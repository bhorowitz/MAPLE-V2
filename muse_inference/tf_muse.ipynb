# %%
from muse_inference import MuseProblem, ScoreAndMAP
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# /tmp/ipykernel_136328/109237086.py in <module>
# ----> 1 from muse_inference import MuseProblem, ScoreAndMAP
#
# ~/muse_inference/muse_inference/muse_inference.py in <module>
#      14 from tqdm import tqdm
#      15
# ---> 16 from .util import pjacobian
#      17
#      18
#
# ImportError: attempted relative import with no known parent package
